-- %%
%sql
CREATE SCHEMA IF NOT EXISTS batch.star_schema;

CREATE TABLE IF NOT EXISTS batch.star_schema.customers (
    customer_id INT,
        name VARCHAR(50),
            country VARCHAR(50),
                signup_date DATE
                );

                INSERT INTO batch.star_schema.customers (customer_id, name, country, signup_date) VALUES
                    (1, 'Alice Johnson', 'United States', '2023-01-15'),
                        (2, 'Bob Smith', 'United Kingdom', '2023-03-22'),
                            (3, 'Clara Müller', 'Germany', '2023-05-10'),
                                (4, 'David Chen', 'China', '2023-07-04'),
                                    (5, 'Emily Davis', 'Canada', '2023-09-18'),
                                        (6, 'François Dupont', 'France', '2023-11-01'),
                                            (7, 'Grace Lee', 'South Korea', '2024-01-30'),
                                                (8, 'Hiroshi Tanaka', 'Japan', '2024-02-14'),
                                                    (9, 'Isabella Rossi', 'Italy', '2024-04-05'),
                                                        (10, 'James Brown', 'Australia', '2024-06-20');

     select * from batch.star_schema.customers
